# %%
import pandas as pd
from tqdm import tqdm
import glob
import datetime as dt
from datetime import datetime
import operator
from pricechange import *
from binanceHelper import *
from pricegroup import *
from order import *

# %%
"""
data_historical içerisinde bulunan veriyi okur,
interval = 1s (1 saniye) için data_historical içerisinde bulunan verinin sonunda "_1s" yazan tüm veriyi okur.
Burada birden fazla veri varsa hepsini otomatik olarak okur

Çıktı:
    Dump ve pump olan coinleri output_pump_dump klasörü içerisine o anın tarihi ile kaydeder.
    Dump ve pump olan coinler data_pump_dump degiskeni ile incelenebilir. Console'a print ile yazılmasına gerek yoktur.
    
    Al ve sat emri çıkan coinler output_buy_sell klasörü içerisine o anın tarihi ile kaydeder.
    
"""
interval = "1s"
show_only_pair = "USDT" #Select nothing for all, only selected currency will be shown,
show_limit = 2      #minimum top query limit
min_perc = 0.2  #min percentage change
volume_threshold = 10

path = !pwd
path = path[0]

# %%
# Read Data
folder_name = "data_historical"
list_file_names = glob.glob(folder_name+"/*")

list_data = []
for file in list_file_names:
    if interval in file:
        data = pd.read_pickle(file)

        data["s"] = len(data)*[file.split("_")[-2]]
        #data['open'] = data['open'].astype(str)
        data.rename(columns={'open': 'c', 'timestamp': 'E'}, inplace=True)

        list_data.append(data)

# %%
# json formatına çevir
list_json_message = []
for i in tqdm(range(len(data))):
    json_message_l = []
    for j in range(len(list_data)):
        data_dummy = list_data[j]
        json_message_l.append(dict(data_dummy.iloc[i, :]))
    list_json_message.append(json_message_l)
# Out:
# 100%|█████████████████████████████████████| 1201/1201 [00:00<00:00, 4304.97it/s]

# %%
list_json_message
# Out:
# [[{'E': 1686048000000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 1334408.0,
#    'close_time': 1686048000999,
#    'quote_asset_volume': '304.37846480',
#    'number_of_trades': 2,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:00'),
#    's': 'EPXUSDT'},
#   {'E': 1686048000000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 1334408.0,
#    'close_time': 1686048000999,
#    'quote_asset_volume': '304.37846480',
#    'number_of_trades': 2,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:00'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048001000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048001999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:01'),
#    's': 'EPXUSDT'},
#   {'E': 1686048001000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048001999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:01'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048002000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048002999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:02'),
#    's': 'EPXUSDT'},
#   {'E': 1686048002000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048002999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:02'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048003000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048003999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:03'),
#    's': 'EPXUSDT'},
#   {'E': 1686048003000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048003999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:03'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048004000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048004999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:04'),
#    's': 'EPXUSDT'},
#   {'E': 1686048004000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048004999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:04'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048005000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048005999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:05'),
#    's': 'EPXUSDT'},
#   {'E': 1686048005000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048005999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:05'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048006000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048006999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:06'),
#    's': 'EPXUSDT'},
#   {'E': 1686048006000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048006999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:06'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048007000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048007999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:07'),
#    's': 'EPXUSDT'},
#   {'E': 1686048007000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048007999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:07'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048008000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048008999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:08'),
#    's': 'EPXUSDT'},
#   {'E': 1686048008000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048008999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:08'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048009000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048009999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:09'),
#    's': 'EPXUSDT'},
#   {'E': 1686048009000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048009999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:09'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048010000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048010999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:10'),
#    's': 'EPXUSDT'},
#   {'E': 1686048010000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048010999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:10'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048011000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048011999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:11'),
#    's': 'EPXUSDT'},
#   {'E': 1686048011000,
#    'c': 0.0002281,
#    'high': 0.0002281,
#    'low': 0.0002281,
#    'close': 0.0002281,
#    'volume': 0.0,
#    'close_time': 1686048011999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:11'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048012000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 438020.0,
#    'close_time': 1686048012999,
#    'quote_asset_volume': '99.99996600',
#    'number_of_trades': 1,
#    'taker_buy_base_asset_volume': '438020.00000000',
#    'taker_buy_quote_asset_volume': '99.99996600',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:12'),
#    's': 'EPXUSDT'},
#   {'E': 1686048012000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 438020.0,
#    'close_time': 1686048012999,
#    'quote_asset_volume': '99.99996600',
#    'number_of_trades': 1,
#    'taker_buy_base_asset_volume': '438020.00000000',
#    'taker_buy_quote_asset_volume': '99.99996600',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:12'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048013000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048013999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:13'),
#    's': 'EPXUSDT'},
#   {'E': 1686048013000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048013999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:13'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048014000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048014999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:14'),
#    's': 'EPXUSDT'},
#   {'E': 1686048014000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048014999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:14'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048015000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048015999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:15'),
#    's': 'EPXUSDT'},
#   {'E': 1686048015000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048015999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:15'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048016000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048016999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:16'),
#    's': 'EPXUSDT'},
#   {'E': 1686048016000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048016999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:16'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048017000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048017999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:17'),
#    's': 'EPXUSDT'},
#   {'E': 1686048017000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048017999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:17'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048018000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048018999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:18'),
#    's': 'EPXUSDT'},
#   {'E': 1686048018000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048018999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:18'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048019000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048019999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:19'),
#    's': 'EPXUSDT'},
#   {'E': 1686048019000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048019999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:19'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048020000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048020999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:20'),
#    's': 'EPXUSDT'},
#   {'E': 1686048020000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048020999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:20'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048021000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048021999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:21'),
#    's': 'EPXUSDT'},
#   {'E': 1686048021000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048021999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:21'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048022000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048022999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:22'),
#    's': 'EPXUSDT'},
#   {'E': 1686048022000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048022999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:22'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048023000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048023999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:23'),
#    's': 'EPXUSDT'},
#   {'E': 1686048023000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048023999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:23'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048024000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048024999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:24'),
#    's': 'EPXUSDT'},
#   {'E': 1686048024000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048024999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:24'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048025000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048025999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:25'),
#    's': 'EPXUSDT'},
#   {'E': 1686048025000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048025999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:25'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048026000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048026999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:26'),
#    's': 'EPXUSDT'},
#   {'E': 1686048026000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048026999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:26'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048027000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048027999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:27'),
#    's': 'EPXUSDT'},
#   {'E': 1686048027000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048027999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:27'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048028000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048028999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:28'),
#    's': 'EPXUSDT'},
#   {'E': 1686048028000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048028999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:28'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048029000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048029999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:29'),
#    's': 'EPXUSDT'},
#   {'E': 1686048029000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048029999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:29'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048030000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048030999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:30'),
#    's': 'EPXUSDT'},
#   {'E': 1686048030000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048030999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:30'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048031000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048031999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:31'),
#    's': 'EPXUSDT'},
#   {'E': 1686048031000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048031999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:31'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048032000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048032999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:32'),
#    's': 'EPXUSDT'},
#   {'E': 1686048032000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048032999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:32'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048033000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048033999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:33'),
#    's': 'EPXUSDT'},
#   {'E': 1686048033000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048033999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:33'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048034000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048034999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:34'),
#    's': 'EPXUSDT'},
#   {'E': 1686048034000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048034999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:34'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048035000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048035999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:35'),
#    's': 'EPXUSDT'},
#   {'E': 1686048035000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048035999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:35'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048036000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048036999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:36'),
#    's': 'EPXUSDT'},
#   {'E': 1686048036000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048036999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:36'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048037000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048037999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:37'),
#    's': 'EPXUSDT'},
#   {'E': 1686048037000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048037999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:37'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048038000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048038999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:38'),
#    's': 'EPXUSDT'},
#   {'E': 1686048038000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048038999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:38'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048039000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048039999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:39'),
#    's': 'EPXUSDT'},
#   {'E': 1686048039000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048039999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:39'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048040000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048040999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:40'),
#    's': 'EPXUSDT'},
#   {'E': 1686048040000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048040999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:40'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048041000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048041999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:41'),
#    's': 'EPXUSDT'},
#   {'E': 1686048041000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048041999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:41'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048042000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048042999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:42'),
#    's': 'EPXUSDT'},
#   {'E': 1686048042000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048042999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:42'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048043000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048043999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:43'),
#    's': 'EPXUSDT'},
#   {'E': 1686048043000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048043999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:43'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048044000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048044999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:44'),
#    's': 'EPXUSDT'},
#   {'E': 1686048044000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048044999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:44'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048045000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048045999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:45'),
#    's': 'EPXUSDT'},
#   {'E': 1686048045000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048045999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:45'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048046000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048046999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:46'),
#    's': 'EPXUSDT'},
#   {'E': 1686048046000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048046999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:46'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048047000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048047999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:47'),
#    's': 'EPXUSDT'},
#   {'E': 1686048047000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048047999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:47'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048048000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048048999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:48'),
#    's': 'EPXUSDT'},
#   {'E': 1686048048000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048048999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:48'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048049000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048049999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:49'),
#    's': 'EPXUSDT'},
#   {'E': 1686048049000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048049999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:49'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048050000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048050999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:50'),
#    's': 'EPXUSDT'},
#   {'E': 1686048050000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048050999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:50'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048051000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048051999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:51'),
#    's': 'EPXUSDT'},
#   {'E': 1686048051000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048051999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:51'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048052000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048052999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:52'),
#    's': 'EPXUSDT'},
#   {'E': 1686048052000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048052999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:52'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048053000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048053999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:53'),
#    's': 'EPXUSDT'},
#   {'E': 1686048053000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048053999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:53'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048054000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048054999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:54'),
#    's': 'EPXUSDT'},
#   {'E': 1686048054000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048054999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:54'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048055000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048055999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:55'),
#    's': 'EPXUSDT'},
#   {'E': 1686048055000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048055999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:55'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048056000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048056999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:56'),
#    's': 'EPXUSDT'},
#   {'E': 1686048056000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048056999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:56'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048057000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048057999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:57'),
#    's': 'EPXUSDT'},
#   {'E': 1686048057000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048057999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:57'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048058000,
#    'c': 0.0002283,
#    'high': 0.0002283,
#    'low': 0.0002283,
#    'close': 0.0002283,
#    'volume': 0.0,
#    'close_time': 1686048058999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:40:58'),
#    's': 'EPXUSDT'},
#   {'E': 1686048058000,
#    'c': 0.0002283,
# ...
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048980999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:20'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048981000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048981999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:21'),
#    's': 'EPXUSDT'},
#   {'E': 1686048981000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048981999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:21'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048982000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048982999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:22'),
#    's': 'EPXUSDT'},
#   {'E': 1686048982000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048982999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:22'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048983000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048983999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:23'),
#    's': 'EPXUSDT'},
#   {'E': 1686048983000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048983999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:23'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048984000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048984999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:24'),
#    's': 'EPXUSDT'},
#   {'E': 1686048984000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048984999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:24'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048985000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048985999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:25'),
#    's': 'EPXUSDT'},
#   {'E': 1686048985000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048985999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:25'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048986000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048986999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:26'),
#    's': 'EPXUSDT'},
#   {'E': 1686048986000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048986999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:26'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048987000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048987999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:27'),
#    's': 'EPXUSDT'},
#   {'E': 1686048987000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048987999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:27'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048988000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048988999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:28'),
#    's': 'EPXUSDT'},
#   {'E': 1686048988000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048988999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:28'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048989000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048989999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:29'),
#    's': 'EPXUSDT'},
#   {'E': 1686048989000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048989999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:29'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048990000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048990999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:30'),
#    's': 'EPXUSDT'},
#   {'E': 1686048990000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048990999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:30'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048991000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 416141.0,
#    'close_time': 1686048991999,
#    'quote_asset_volume': '95.17144670',
#    'number_of_trades': 1,
#    'taker_buy_base_asset_volume': '416141.00000000',
#    'taker_buy_quote_asset_volume': '95.17144670',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:31'),
#    's': 'EPXUSDT'},
#   {'E': 1686048991000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 416141.0,
#    'close_time': 1686048991999,
#    'quote_asset_volume': '95.17144670',
#    'number_of_trades': 1,
#    'taker_buy_base_asset_volume': '416141.00000000',
#    'taker_buy_quote_asset_volume': '95.17144670',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:31'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048992000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048992999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:32'),
#    's': 'EPXUSDT'},
#   {'E': 1686048992000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048992999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:32'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048993000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048993999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:33'),
#    's': 'EPXUSDT'},
#   {'E': 1686048993000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048993999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:33'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048994000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048994999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:34'),
#    's': 'EPXUSDT'},
#   {'E': 1686048994000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048994999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:34'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048995000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048995999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:35'),
#    's': 'EPXUSDT'},
#   {'E': 1686048995000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048995999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:35'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048996000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048996999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:36'),
#    's': 'EPXUSDT'},
#   {'E': 1686048996000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048996999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:36'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048997000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048997999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:37'),
#    's': 'EPXUSDT'},
#   {'E': 1686048997000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048997999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:37'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048998000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048998999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:38'),
#    's': 'EPXUSDT'},
#   {'E': 1686048998000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048998999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:38'),
#    's': 'EPXUSDT'}],
#  [{'E': 1686048999000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048999999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:39'),
#    's': 'EPXUSDT'},
#   {'E': 1686048999000,
#    'c': 0.0002287,
#    'high': 0.0002287,
#    'low': 0.0002287,
#    'close': 0.0002287,
#    'volume': 0.0,
#    'close_time': 1686048999999,
#    'quote_asset_volume': '0.00000000',
#    'number_of_trades': 0,
#    'taker_buy_base_asset_volume': '0.00000000',
#    'taker_buy_quote_asset_volume': '0.00000000',
#    'ignore': '0',
#    'event_time': Timestamp('2023-06-06 13:56:39'),
#    's': 'EPXUSDT'}],
#  ...]

# %%
# Backtest
price_changes = []
price_groups = {}

TRADED_COIN = []       

previous_price_groups = []
copy_previous_price_groups = []
list_pump_dump = []
list_buy_sell = []

for json_message in tqdm(list_json_message):

    # print("on_message")
    
    # price_changes listesinin icerisine PriceChange sınıfına ait nesneleri ekliyor.
    for ticker in json_message: # json_message is a list that includes dictionaries.
        symbol = ticker['s']
        
        if ('USDT' in symbol and  not 'BUSDT' in symbol): #BUSDT ???

            price = float(ticker['c']) # Last price
            volume = float(ticker['volume']) # volume
            number_of_trades = int(ticker['number_of_trades']) # number_of_trades ???
            event_time = dt.datetime.fromtimestamp(int(ticker['E'])/1000)

            if len(price_changes) > 0:
                price_change = filter(lambda item: item.symbol == symbol, price_changes)
                price_change = list(price_change)
                if (len(price_change) > 0):
                    price_change = price_change[0]
                    price_change.all_prices.append(price) 
                    price_change.event_time = event_time
                    price_change.prev_price = price_change.price
                    price_change.price = price
                    price_change.volume = volume
                    price_change.number_of_trades = number_of_trades
                    price_change.isPrinted = False
                    price_change.is_refresh_list = False
                else:
                    price_changes.append(PriceChange(symbol, price, price,  False, event_time, price, False, volume, number_of_trades))
            else:
                price_changes.append(PriceChange(symbol, price, price, False, event_time, price, False, volume, number_of_trades))

    price_changes.sort(key=operator.attrgetter('price_change_perc'), reverse=True)
        
    for price_change in price_changes:
        
        console_color = 'green'
        temp_price_change  = price_change.price_change_perc
        if  temp_price_change < 0:
            console_color = 'red'

        if (not price_change.isPrinted and abs(temp_price_change) >= min_perc) :

            price_change.isPrinted = True 
            
            # volume filtresi ekle
            if price_change.volume >= volume_threshold:
                if not price_change.symbol in price_groups:
                    price_groups[price_change.symbol] = PriceGroup(price_change.symbol,                                                                
                                                                1,                                                                
                                                                abs(temp_price_change),
                                                                temp_price_change,                                                            
                                                                price_change.price,                                                                                                                             
                                                                price_change.event_time,
                                                                False,
                                                                min(price_change.all_prices),
                                                                max(price_change.all_prices),
                                                                price_change.volume,
                                                                price_change.number_of_trades)
                else:
                    # Eğer anlık fiyat şimdiye kadar gelen fiyatların maksimum değerinin 0.998 katından büyükse yada
                    # anlık fiyat şimdiye kadar gelen fiyatların minimum değerinin 1.002 katından küçükse
                    # tutulan verinin son fiyatı güncelleniyor (burada her veri tutulmasın diye basit bir kural eklenmiş)
                    if ((price_change.price >= (price_groups[price_change.symbol].max_price)*0.998) or 
                        (price_change.price <= (price_groups[price_change.symbol].min_price)*1.002)):
    
                        price_groups[price_change.symbol].tick_count += 1
                        price_groups[price_change.symbol].last_event_time = price_change.event_time
                        price_groups[price_change.symbol].last_price = price_change.price
                        price_groups[price_change.symbol].isPrinted = False
                        price_groups[price_change.symbol].total_price_change = abs(temp_price_change)
                        price_groups[price_change.symbol].relative_price_change = temp_price_change 
                        price_groups[price_change.symbol].min_price = min(price_change.all_prices)      
                        price_groups[price_change.symbol].max_price = max(price_change.all_prices)   
                        price_groups[price_change.symbol].volume = price_change.volume 
                        price_groups[price_change.symbol].number_of_trades = price_change.number_of_trades
    
                    if price_change.is_refresh_list:
                        price_groups[price_change.symbol].refresh_datas

        if abs(temp_price_change) < min_perc:
            break            

    if len(price_groups)>0:
        anyPrinted = False 

        sorted_price_group = sorted(price_groups, key=lambda k:price_groups[k]['total_price_change'])
        if (len(sorted_price_group)>0):
            sorted_price_group = list(reversed(sorted_price_group))
            sorted_price_group = sorted_price_group[:3]    
            # print("sorted_price_group: ",sorted_price_group)

            if len(previous_price_groups) > 0:

                copy_previous_price_groups = previous_price_groups.copy()

                for s in range(0,len(copy_previous_price_groups)):

                    if (not copy_previous_price_groups[s] in sorted_price_group) or (price_groups[copy_previous_price_groups[s]].isPrinted):

                        #  if you dont want to create order, comment line start from here 

                        # if (not TRADED_COIN.count(price_groups[copy_previous_price_groups[s]].symbol) > 0  and not order.getOpenOrder())  and order.isAnyLiquidation():
                        if not TRADED_COIN.count(price_groups[copy_previous_price_groups[s]].symbol) > 0:

                            if price_groups[copy_previous_price_groups[s]].relative_price_change > 0: 
                                # order.enterShortOrder(symbol = price_groups[copy_previous_price_groups[s]].symbol
                                #                     ,price =  price_groups[copy_previous_price_groups[s]].last_price   
                                #                     ,type = 'MARKET')
  
                                explanation = 'Enter Short ' 
                                # print(explanation, ' ',price_groups[copy_previous_price_groups[s]].symbol)

                                TRADED_COIN.append(price_groups[copy_previous_price_groups[s]].symbol)
                                list_buy_sell.append(price_groups[copy_previous_price_groups[s]].to_list("short"))
                            else:
                                # order.enterLongOrder(symbol = price_groups[copy_previous_price_groups[s]].symbol
                                #                     ,price = price_groups[copy_previous_price_groups[s]].last_price   
                                #                     ,type = 'MARKET')     

                                explanation = 'Enter Long '                                  
                                # print(explanation, ' ',price_groups[copy_previous_price_groups[s]].symbol)

                                TRADED_COIN.append(price_groups[copy_previous_price_groups[s]].symbol) 
                                list_buy_sell.append(price_groups[copy_previous_price_groups[s]].to_list("long"))
                        # aynı coin için işleme girmemek adına yapılmış.
                        # elif  TRADED_COIN.count(price_groups[copy_previous_price_groups[s]].symbol) > 0:
                        #     if not order.getOpenOrder(price_groups[copy_previous_price_groups[s]].symbol):
                        #         TRADED_COIN.remove(price_groups[copy_previous_price_groups[s]].symbol)  

                        # to here

                        previous_price_groups.remove(copy_previous_price_groups[s])


            for s in range(show_limit):
                header_printed=False
                if (s<len(sorted_price_group)):
                    max_price_group = sorted_price_group[s]
                    max_price_group = price_groups[max_price_group]
                    if not max_price_group.isPrinted :  
                            if not header_printed:
                                msg = "Top Total Price Change"
                                header_printed = True 
                            str_output = max_price_group.to_string(True) + "\n"
                            print(str_output)
                            list_pump_dump.append(max_price_group.to_list())
                            anyPrinted = True                           
                            previous_price_groups.append(max_price_group.symbol) if max_price_group.symbol not in previous_price_groups else previous_price_groups
# Out:
# 100%|████████████████████████████████████| 1201/1201 [00:00<00:00, 13610.95it/s]
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:46:08	 Now_Time: 15:56:16.108867	 Ticks:1	 RPCh:-0.22	  LP:0.000228	  MinP:0.000228	 MaxP: 0.0002285	 Vol: 50178.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:47:49	 Now_Time: 15:56:16.118889	 Ticks:2	 RPCh:-0.22	  LP:0.000228	  MinP:0.000228	 MaxP: 0.0002285	 Vol: 90666.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:48:03	 Now_Time: 15:56:16.120235	 Ticks:3	 RPCh:-0.22	  LP:0.000228	  MinP:0.000228	 MaxP: 0.0002285	 Vol: 4136645.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:52:31	 Now_Time: 15:56:16.142156	 Ticks:4	 RPCh:0.22	  LP:0.0002285	  MinP:0.000228	 MaxP: 0.0002285	 Vol: 95842.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:52:48	 Now_Time: 15:56:16.143583	 Ticks:5	 RPCh:0.22	  LP:0.0002285	  MinP:0.000228	 MaxP: 0.0002285	 Vol: 1636228.0	 NoT: 3	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:52:56	 Now_Time: 15:56:16.144302	 Ticks:6	 RPCh:0.26	  LP:0.0002286	  MinP:0.000228	 MaxP: 0.0002286	 Vol: 940371.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:53:02	 Now_Time: 15:56:16.144829	 Ticks:7	 RPCh:0.26	  LP:0.0002286	  MinP:0.000228	 MaxP: 0.0002286	 Vol: 47961.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:54:01	 Now_Time: 15:56:16.150047	 Ticks:8	 RPCh:0.22	  LP:0.0002285	  MinP:0.000228	 MaxP: 0.0002286	 Vol: 659504.0	 NoT: 2	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:55:10	 Now_Time: 15:56:16.156369	 Ticks:9	 RPCh:0.22	  LP:0.0002287	  MinP:0.0002282	 MaxP: 0.0002287	 Vol: 165639.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:55:36	 Now_Time: 15:56:16.157877	 Ticks:10	 RPCh:0.22	  LP:0.0002287	  MinP:0.0002282	 MaxP: 0.0002287	 Vol: 151481.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:55:40	 Now_Time: 15:56:16.158140	 Ticks:11	 RPCh:0.22	  LP:0.0002287	  MinP:0.0002282	 MaxP: 0.0002287	 Vol: 75741.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:56:31	 Now_Time: 15:56:16.161513	 Ticks:12	 RPCh:0.22	  LP:0.0002287	  MinP:0.0002282	 MaxP: 0.0002287	 Vol: 416141.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:57:38	 Now_Time: 15:56:16.166811	 Ticks:13	 RPCh:0.22	  LP:0.0002287	  MinP:0.0002282	 MaxP: 0.0002287	 Vol: 2248259.0	 NoT: 4	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:59:07	 Now_Time: 15:56:16.174698	 Ticks:14	 RPCh:0.22	  LP:0.0002287	  MinP:0.0002282	 MaxP: 0.0002289	 Vol: 1757154.0	 NoT: 3	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:59:27	 Now_Time: 15:56:16.176633	 Ticks:15	 RPCh:0.22	  LP:0.0002287	  MinP:0.0002282	 MaxP: 0.0002289	 Vol: 275766.0	 NoT: 1	 LTP: 0.0	 LTPC: 0
#
# Symbol:EPXUSDT	 Event_Time:2023-06-06 13:59:50	 Now_Time: 15:56:16.179142	 Ticks:16	 RPCh:0.22	  LP:0.0002287	  MinP:0.0002282	 MaxP: 0.0002289	 Vol: 87450.0	 NoT: 1	 LTP: 0.0	 LTPC: 0

# %%
ticker
# Out:
# {'E': 1686049200000,
#  'c': 0.0002287,
#  'high': 0.0002287,
#  'low': 0.0002287,
#  'close': 0.0002287,
#  'volume': 0.0,
#  'close_time': 1686049200999,
#  'quote_asset_volume': '0.00000000',
#  'number_of_trades': 0,
#  'taker_buy_base_asset_volume': '0.00000000',
#  'taker_buy_quote_asset_volume': '0.00000000',
#  'ignore': '0',
#  'event_time': Timestamp('2023-06-06 14:00:00'),
#  's': 'EPXUSDT'}

# %%
data_pump_dump = pd.DataFrame(list_pump_dump, columns = ["Symbol", "Event_Time", 
                                                         "Now_Time", "Ticks", 
                                                         "RPCh", "LP", "MinP", "MaxP", "volume", "number_of_trades",
                                                         "LTP", "LTPC",
                                                         "color","order_type"])    
data_buy_sell = pd.DataFrame(list_buy_sell, columns = ["Symbol", "Event_Time", 
                                                         "Now_Time", "Ticks", 
                                                         "RPCh", "LP", "MinP", "MaxP", "volume", "number_of_trades",
                                                         "LTP", "LTPC",
                                                         "color","order_type"])

# %%
# save result

date_now = datetime.now().strftime("%Y%m%d_%H%M%S")
data_pump_dump.to_pickle("output_pump_dump\\"+date_now)  
data_buy_sell.to_pickle("output_buy_sell\\"+date_now)
